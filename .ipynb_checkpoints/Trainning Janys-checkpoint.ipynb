# %%
# !pip install wandb
import wandb
wandb.init()
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 11.9 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 479.1/479.1 KB 18.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.2/181.2 KB 3.3 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.3/145.3 KB 4.8 MB/s eta 0:00:00
# ...
#   Using cached gitdb-4.0.9-py3-none-any.whl (63 kB)
# ...
#   Using cached smmap-5.0.0-py3-none-any.whl (24 kB)
# ...
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21503 sha256=4a5be2b93f939eb2ecfb86ef46fbadfe807fd92223628cf0bf4de0dbd68a6efe
#   Stored in directory: /Users/arthurspriet/Library/Caches/pip/wheels/54/4e/28/3ed0e1c8a752867445bab994d2340724928aa3ab059c57c8db
# ...

# %%
# !mkdir -content
# Out:
# mkdir: illegal option -- c
# usage: mkdir [-pv] [-m mode] directory ...

# %%
# %cd /content
# Out:
# [Errno 2] No such file or directory: '/content'
# /Users/arthurspriet/Desktop/Tensorflow

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 10323, done.
# remote: Total 10323 (delta 0), reused 0 (delta 0), pack-reused 10323
# Receiving objects: 100% (10323/10323), 10.56 MiB | 19.21 MiB/s, done.
# Resolving deltas: 100% (7127/7127), done.
# /content/yolov5
#      |████████████████████████████████| 596 kB 5.6 MB/s

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
wandb.init()
# Out:
# Finishing last run (ID:2v28oamb) before initializing another...
# <br/>Waiting for W&B process to finish, PID 160... <strong style="color:green">(success).</strong>
# ...
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# </div><div class="wandb-col">
# </div></div>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# <br/>Synced <strong style="color:#cdcd00">light-terrain-6</strong>: <a href="https://wandb.ai/arthurspriet/uncategorized/runs/2v28oamb" target="_blank">https://wandb.ai/arthurspriet/uncategorized/runs/2v28oamb</a><br/>
# Find logs at: <code>/content/wandb/run-20211221_142459-2v28oamb/logs</code><br/>
# ...

# %%
import torch
from torch import hub # Hub contains other models like FasterRCNN
model = torch.hub.load( \
                      'ultralytics/yolov5', \
                      'yolov5s', \
                      pretrained=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to /root/.cache/torch/hub/master.zip
# ...
# requirements: PyYAML>=5.3.1 not found and is required by YOLOv5, attempting auto-update...
# YOLOv5 🚀 2021-12-21 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
# ...
#
# requirements: 1 package updated per /root/.cache/torch/hub/ultralytics_yolov5_master/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# ...
#   0%|          | 0.00/14.0M [00:00<?, ?B/s]
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
# !python train.py --img 640 --batch 25 --epochs 300 --data lacarata.yml  --weights yolov5s.pt --cache
# Out:
# wandb: Currently logged in as: arthurspriet (use `wandb login --relogin` to force relogin)
# train: weights=yolov5s.pt, cfg=, data=lacarata.yml, hyp=data/hyps/hyp.scratch.yaml, epochs=300, batch_size=25, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-155-gdc54ed5 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
torch.save(model.state_dict(), 'checkpoint.pth')
torch.save(model, 'model.pth')
from google.colab import files
# !zip -r /content/file.zip /content/yolov5
files.download('./content/yolov5')
# Out:
# updating: content/yolov5/ (stored 0%)
# updating: content/yolov5/__pycache__/ (stored 0%)
# updating: content/yolov5/__pycache__/val.cpython-37.pyc (deflated 41%)
# updating: content/yolov5/Dockerfile (deflated 56%)
# updating: content/yolov5/labels/ (stored 0%)
# updating: content/yolov5/labels/test/ (stored 0%)
# updating: content/yolov5/labels/test/Hello.dde523ea-5de7-11ec-aaa6-0e286d93875c.txt (deflated 11%)
# updating: content/yolov5/labels/test/Goodbye.e87b0022-5de7-11ec-aaa6-0e286d93875c.txt (deflated 8%)
# updating: content/yolov5/labels/test/Hello.f68b8158-5dda-11ec-aaa6-0e286d93875c.txt (deflated 5%)
# updating: content/yolov5/labels/test/Goodbye.d42b5566-5dda-11ec-aaa6-0e286d93875c.txt (deflated 5%)
# updating: content/yolov5/labels/test/Goodbye.e73aa208-5de7-11ec-aaa6-0e286d93875c.txt (deflated 5%)
# updating: content/yolov5/labels/test/Goodbye.67fe789a-5e58-11ec-a491-0e286d93875d.txt (deflated 8%)
# ...

# %%
#!zip -r /content/file.zip /content/yolov5
from google.colab import files
files.download("/content/file.zip")

# %%
## for later 
from google.colab import drive
drive.mount('/content/gdrive')



print("Our model: \n\n", model, '\n')
print("The state dict keys: \n\n", model.state_dict().keys())
